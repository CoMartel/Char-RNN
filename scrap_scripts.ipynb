# %%
import glob
import os

# %%
rootdir = "./pandas/"
# rootdir = "./data/django-master/"

# %%
for root, subdirs, files in os.walk(rootdir):
#     print(root)
#     print(subdirs)
#     print("files : {}".format(files))
    py_files = [f for f in files if (f[-3:]==".py" and
                                     f != "__init__.py" and
                                     f != "setup.py" and
                                     f != "config.py"
                                    )]
#     print(py_files)
    with open("./data/full_pandas.py","a",encoding="utf-8") as save_file:
        to_save = ""
        for f in py_files:
            with open(os.path.join(root, f),"r",encoding="utf-8") as py_file:
                f_content = py_file.read()
                if f_content.startswith('import'):
                    print(f)
#                 print(f_content)
                    save_file.write(f_content)
                    save_file.write('\n')
# Out:
# attrs_caching.py
# binary_ops.py
# categoricals.py
# ctors.py
# eval.py
# frame_ctor.py
# frame_methods.py
# gil.py
# indexing.py
# indexing_engines.py
# index_object.py
# inference.py
# join_merge.py
# multiindex_object.py
# pandas_vb_common.py
# panel_ctor.py
# panel_methods.py
# plotting.py
# reindex.py
# replace.py
# reshape.py
# rolling.py
# sparse.py
# stat_ops.py
# strings.py
# timedelta.py
# timestamp.py
# csv.py
# excel.py
# hdf.py
# json.py
# msgpack.py
# pickle.py
# sas.py
# sql.py
# stata.py
# chainmap_impl.py
# apply.py
# categorical.py
# resample.py
# integer.py
# numpy_.py
# common.py
# categorical.py
# api.py
# category.py
# numeric.py
# util.py
# numeric.py
# clipboards.py
# exceptions.py
# _converter.py
# test_register_accessor.py
# test_array.py
# test_period.py
# conftest.py
# test_algos.py
# test_arithmetics.py
# test_array.py
# test_dtype.py
# test_libsparse.py
# conftest.py
# test_common.py
# test_datetime.py
# test_numpy.py
# test_period.py
# test_sparse.py
# ...

# %%
root
# Out:
# './pandas/scripts\\tests'
